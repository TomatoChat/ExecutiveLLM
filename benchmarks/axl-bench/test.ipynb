# %%
import axelrod as axl
import pprint
from src.strategies.Test import MyMimic
from src.prompts.contextualized import STRATEGY_PREDETERMINED_TURNS_FULL_HISTORY
from src.models import PromptContext

# %%
PromptContext(
    promptTemplate=STRATEGY_PREDETERMINED_TURNS_FULL_HISTORY,
    personalHistory=[],
    opponentHistory=[],
    historyLastTurns=None,
    numTurns=None,
    endProbability=None

# %%
template.format(**variables)

# %%
players = [MyMimic(), axl.Cooperator(), axl.Defector(),
           axl.TitForTat(), axl.Grudger()]
players.append(axl.Random())
tournament = axl.Tournament(players, turns=5, prob_end=0.5, seed=101)
results = tournament.play(processes=0)
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 302.27it/s]

# %% [markdown]
# **Printing summaries**

# %%
summary = results.summarise()
pprint.pprint(summary)
# Out:
# [Player(Rank=0, Name='Defector', Median_score=np.float64(3.9466666666666668), Cooperation_rating=0.0, Wins=np.float64(5.0), Initial_C_rate=np.float64(0.0), Original_index=2, CC_rate=0.0, CD_rate=0.0, DC_rate=0.6307422969187675, DD_rate=0.3692577030812325, CC_to_C_rate=0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
#  Player(Rank=1, Name='Random: 0.5', Median_score=np.float64(2.635), Cooperation_rating=0.5, Wins=np.float64(1.0), Initial_C_rate=np.float64(0.54), Original_index=5, CC_rate=0.29561976837518633, CD_rate=0.214703425229741, DC_rate=0.3036005045292971, DD_rate=0.18607630186577553, CC_to_C_rate=np.float64(0.5), CD_to_C_rate=np.float64(0.6666666666666666), DC_to_C_rate=np.float64(0.5833333333333334), DD_to_C_rate=np.float64(0.5357142857142857)),
# ...

# %%
plot = axl.Plot(results)
p = plot.boxplot()
p.show()
# Out:
# /var/folders/df/d61ry_6j4qbd1b9znf2j4w0h0000gn/T/ipykernel_94475/2188283945.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
# distributions of wins for each strategy
p = plot.winplot()
p.show()
# Out:
# /var/folders/df/d61ry_6j4qbd1b9znf2j4w0h0000gn/T/ipykernel_94475/3144341313.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()

# %%
# payoff matrix
p = plot.payoff()
p.show()
# Out:
# /var/folders/df/d61ry_6j4qbd1b9znf2j4w0h0000gn/T/ipykernel_94475/3964331733.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.show()
